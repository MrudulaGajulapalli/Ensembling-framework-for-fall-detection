# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt

def load_video_frames(folder_path):
    """Load all frames from a given folder."""
    frame_files = sorted([f for f in os.listdir(folder_path) if f.endswith('.png')])
    frames = [cv2.imread(os.path.join(folder_path, f), cv2.IMREAD_GRAYSCALE) for f in frame_files]
    return frames

def compute_mhi(frames, duration=30):
    """Compute the Motion History Image (MHI) from a sequence of frames."""
    height, width = frames[0].shape
    mhi = np.zeros((height, width), dtype=np.float32)
    timestamp = 1  # Start timestamp
    
    for i in range(1, len(frames)):
        diff = cv2.absdiff(frames[i], frames[i - 1])
        _, motion_mask = cv2.threshold(diff, 30, 1, cv2.THRESH_BINARY)
        mhi = np.where(motion_mask > 0, timestamp, mhi - 1)
        mhi[mhi < 0] = 0  # Keep non-negative values
        timestamp += 1
    
    # Normalize MHI to 0-255 for visualization
    mhi = (mhi / np.max(mhi) * 255).astype(np.uint8)
    return mhi

# Define the main dataset path
dataset_path = r"E:\Fall Detection Dataset\nonfall_cam1\nfDatasets"
output_folder = os.path.join(r"E:\Fall Detection Dataset", "MHI_nonfall")
os.makedirs(output_folder, exist_ok=True)

# Get all video folders
video_folders = sorted(os.listdir(dataset_path))

for video_folder in video_folders:
    folder_path = os.path.join(dataset_path, video_folder)
    if os.path.isdir(folder_path):
        frames = load_video_frames(folder_path)
        if frames:
            mhi_image = compute_mhi(frames)
            output_path = os.path.join(output_folder, f"{video_folder}_MHI.png")
            cv2.imwrite(output_path, mhi_image)
            print(f"Saved: {output_path}")

print("All MHIs saved successfully.")
# Out:
# Saved: E:\Fall Detection Dataset\MHI_nonfall\adl-01-cam0-rgb_MHI.png
# Saved: E:\Fall Detection Dataset\MHI_nonfall\adl-02-cam0-rgb_MHI.png
# Saved: E:\Fall Detection Dataset\MHI_nonfall\adl-03-cam0-rgb_MHI.png
# Saved: E:\Fall Detection Dataset\MHI_nonfall\adl-04-cam0-rgb_MHI.png
# Saved: E:\Fall Detection Dataset\MHI_nonfall\adl-05-cam0-rgb_MHI.png
# Saved: E:\Fall Detection Dataset\MHI_nonfall\adl-06-cam0-rgb_MHI.png
# Saved: E:\Fall Detection Dataset\MHI_nonfall\adl-07-cam0-rgb_MHI.png
# Saved: E:\Fall Detection Dataset\MHI_nonfall\adl-08-cam0-rgb_MHI.png
# Saved: E:\Fall Detection Dataset\MHI_nonfall\adl-09-cam0-rgb_MHI.png
# Saved: E:\Fall Detection Dataset\MHI_nonfall\adl-10-cam0-rgb_MHI.png
# Saved: E:\Fall Detection Dataset\MHI_nonfall\adl-11-cam0-rgb_MHI.png
# Saved: E:\Fall Detection Dataset\MHI_nonfall\adl-12-cam0-rgb_MHI.png
# Saved: E:\Fall Detection Dataset\MHI_nonfall\adl-13-cam0-rgb_MHI.png
# Saved: E:\Fall Detection Dataset\MHI_nonfall\adl-14-cam0-rgb_MHI.png
# Saved: E:\Fall Detection Dataset\MHI_nonfall\adl-15-cam0-rgb_MHI.png
# Saved: E:\Fall Detection Dataset\MHI_nonfall\adl-16-cam0-rgb_MHI.png
# Saved: E:\Fall Detection Dataset\MHI_nonfall\adl-17-cam0-rgb_MHI.png
# Saved: E:\Fall Detection Dataset\MHI_nonfall\adl-18-cam0-rgb_MHI.png
# Saved: E:\Fall Detection Dataset\MHI_nonfall\adl-19-cam0-rgb_MHI.png
# Saved: E:\Fall Detection Dataset\MHI_nonfall\adl-20-cam0-rgb_MHI.png
# Saved: E:\Fall Detection Dataset\MHI_nonfall\adl-21-cam0-rgb_MHI.png
# Saved: E:\Fall Detection Dataset\MHI_nonfall\adl-22-cam0-rgb_MHI.png
# Saved: E:\Fall Detection Dataset\MHI_nonfall\adl-23-cam0-rgb_MHI.png
# Saved: E:\Fall Detection Dataset\MHI_nonfall\adl-24-cam0-rgb_MHI.png
# Saved: E:\Fall Detection Dataset\MHI_nonfall\adl-25-cam0-rgb_MHI.png
# Saved: E:\Fall Detection Dataset\MHI_nonfall\adl-26-cam0-rgb_MHI.png
# Saved: E:\Fall Detection Dataset\MHI_nonfall\adl-27-cam0-rgb_MHI.png
# Saved: E:\Fall Detection Dataset\MHI_nonfall\adl-28-cam0-rgb_MHI.png
# Saved: E:\Fall Detection Dataset\MHI_nonfall\adl-29-cam0-rgb_MHI.png
# Saved: E:\Fall Detection Dataset\MHI_nonfall\adl-30-cam0-rgb_MHI.png
# Saved: E:\Fall Detection Dataset\MHI_nonfall\adl-31-cam0-rgb_MHI.png
# Saved: E:\Fall Detection Dataset\MHI_nonfall\adl-32-cam0-rgb_MHI.png
# Saved: E:\Fall Detection Dataset\MHI_nonfall\adl-33-cam0-rgb_MHI.png
# Saved: E:\Fall Detection Dataset\MHI_nonfall\adl-34-cam0-rgb_MHI.png
# Saved: E:\Fall Detection Dataset\MHI_nonfall\adl-35-cam0-rgb_MHI.png
# Saved: E:\Fall Detection Dataset\MHI_nonfall\adl-36-cam0-rgb_MHI.png
# Saved: E:\Fall Detection Dataset\MHI_nonfall\adl-37-cam0-rgb_MHI.png
# Saved: E:\Fall Detection Dataset\MHI_nonfall\adl-38-cam0-rgb_MHI.png
# Saved: E:\Fall Detection Dataset\MHI_nonfall\adl-39-cam0-rgb_MHI.png
# Saved: E:\Fall Detection Dataset\MHI_nonfall\adl-40-cam0-rgb_MHI.png
# All MHIs saved successfully.
